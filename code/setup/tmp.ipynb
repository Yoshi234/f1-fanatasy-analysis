# %%
import pandas as pd
import fastf1
from set_standings import get_standings_data
import numpy as np

# %%
from fetch_new_dat import fetch_new

# %%
monaco = fastf1.get_session(2024, 'monaco', 'q')
monaco.load()

# %%
schedule = fastf1.get_event_schedule(2024)
schedule

# %%
x2 = pd.read_feather("../../data/clean_model_data.feather")

# %%
x = fetch_new('2024-11-17', test=False)

# %%
x2.loc[(x2['year']==2023), 'round'].max()
# Out:
# 12

# %%
x = pd.read_csv("../../data/clean_model_data2.csv")
x.shape
# Out:
# (6376, 73)

# %%
idx = 0
k1 = x[x2.keys()].keys()
k2 = x2.keys()
while idx < k2.shape[0]:
    if k1[idx] != k2[idx]: 
        print("[ERROR]: mismatched keys {} != {}".format(k1[idx], k2[idx]))
        break
    idx += 1

# %%
x3 = fetch_new('2023-12-01', test=False)
# Out:
# core           INFO 	Loading data for Dutch Grand Prix - Race [v3.4.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '14', '10', '11', '55', '44', '4', '23', '81', '31', '18', '27', '40', '77', '22', '20', '63', '24', '16', '2']
# core           INFO 	Loading data for Dutch Grand Prix - Qualifying [v3.4.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# ...

# %%
x2 = pd.read_csv("../../data/clean_model_data2.csv")
x2 = x2.drop('Unnamed: 0', axis=1)
x2.to_csv("../../data/clean_model_data2.csv", index=False)

# %%
x3[x2.keys()]
# Out:
#     circuitId alt  raceId  year  round        event_name  tempmax  tempmin  \
# 0          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 1          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 2          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 3          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 4          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 5          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 6          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 7          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 8          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 9          39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# 10         39   6    1111  2023     13  Dutch Grand Prix      NaN      NaN
# ...

# %%
x[x2.keys()].keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'round', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'driverId',
#        'constructorId', 'grid', 'positionOrder', 'points', 'laps',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'prev_round', 'prev_driver_points', 'prev_driver_position',
#        'prev_driver_wins', 'prev_construct_points', 'prev_construct_position',
#        'prev_construct_wins', 'ref_year', 'ref_name', 'ref_name',
#        'strt_len_mean', 'strt_len_q1', 'strt_len_median', 'strt_len_q3',
#        'strt_len_max', 'strt_len_min', 'str_len_std', 'avg_track_spd',
#        'max_track_spd', 'min_track_spd', 'std_track_spd', 'corner_spd_mean',
#        'corner_spd_q1', 'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
# ...

# %%
x2.keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'round', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'driverId',
#        'constructorId', 'grid', 'positionOrder', 'points', 'laps',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'prev_round', 'prev_driver_points', 'prev_driver_position',
#        'prev_driver_wins', 'prev_construct_points', 'prev_construct_position',
#        'prev_construct_wins', 'ref_year', 'ref_name', 'strt_len_mean',
#        'strt_len_q1', 'strt_len_median', 'strt_len_q3', 'strt_len_max',
#        'strt_len_min', 'str_len_std', 'avg_track_spd', 'max_track_spd',
#        'min_track_spd', 'std_track_spd', 'corner_spd_mean', 'corner_spd_q1',
#        'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
# ...

# %%
x['resultId'].max()
# Out:
# 26504.0

# %%
x[x2.keys()].shape
# Out:
# (419, 73)

# %%
x2.shape
# Out:
# (5757, 72)

# %%
pd.concat([x[x2.keys()].reset_index(drop=True), x2.reset_index(drop=True)], axis=0)
# Out:
#       circuitId   alt  raceId  year  round          event_name  tempmax  \
# 0             3     7    1111  2024      1  Bahrain Grand Prix      NaN
# 1             3     7    1111  2024      1  Bahrain Grand Prix      NaN
# 2             3     7    1111  2024      1  Bahrain Grand Prix      NaN
# 3             3     7    1111  2024      1  Bahrain Grand Prix      NaN
# 4             3     7    1111  2024      1  Bahrain Grand Prix      NaN
# ...         ...   ...     ...   ...    ...                 ...      ...
# 5752         79  13.0    1102  2023      5    Miami Grand Prix     27.9
# 5753         79  13.0    1102  2023      5    Miami Grand Prix     27.9
# 5754         79  13.0    1102  2023      5    Miami Grand Prix     27.9
# 5755         79  13.0    1102  2023      5    Miami Grand Prix     27.9
# 5756         79  13.0    1102  2023      5    Miami Grand Prix     27.9
#
#       tempmin  temp   dew  ...  chastech_reg  sporting_reg  pitstop_reg  \
# ...

# %%
x[x2.keys()]
# Out:
#      circuitId  alt  raceId  year  round            event_name  tempmax  \
# 0            3    7    1111  2024      1    Bahrain Grand Prix      NaN
# 1            3    7    1111  2024      1    Bahrain Grand Prix      NaN
# 2            3    7    1111  2024      1    Bahrain Grand Prix      NaN
# 3            3    7    1111  2024      1    Bahrain Grand Prix      NaN
# 4            3    7    1111  2024      1    Bahrain Grand Prix      NaN
# ..         ...  ...     ...   ...    ...                   ...      ...
# 414         18  785    1131  2024     21  São Paulo Grand Prix      NaN
# 415         18  785    1131  2024     21  São Paulo Grand Prix      NaN
# 416         18  785    1131  2024     21  São Paulo Grand Prix      NaN
# 417         18  785    1131  2024     21  São Paulo Grand Prix      NaN
# 418         18  785    1131  2024     21  São Paulo Grand Prix      NaN
#
#      tempmin  temp  dew  ...  chastech_reg  sporting_reg  pitstop_reg  \
# ...

# %%
na_vals = x.isna().sum()
for i in range(len(na_vals)):
    print('[INFO]: {} : {}'.format(na_vals.index[i], na_vals[i]))
# Out:
# [INFO]: DriverNumber : 0
# [INFO]: BroadcastName : 0
# [INFO]: Abbreviation : 0
# [INFO]: DriverId : 0
# [INFO]: TeamName : 0
# [INFO]: TeamColor : 0
# [INFO]: TeamId : 0
# [INFO]: FirstName : 0
# [INFO]: LastName : 0
# [INFO]: FullName : 0
# [INFO]: HeadshotUrl : 0
# [INFO]: CountryCode : 0
# [INFO]: positionOrder : 0
# [INFO]: ClassifiedPosition : 0
# [INFO]: grid : 0
# [INFO]: q1 : 419
# [INFO]: q2 : 419
# [INFO]: q3 : 419
# [INFO]: Time : 171
# [INFO]: Status : 0
# [INFO]: points : 0
# [INFO]: alt : 0
# [INFO]: raceId : 0
# [INFO]: round : 0
# [INFO]: ref_name : 0
# [INFO]: event_name : 0
# [INFO]: circuitId : 0
# [INFO]: ref_year : 0
# [INFO]: ref_name : 0
# [INFO]: strt_len_mean : 0
# [INFO]: strt_len_q1 : 0
# [INFO]: strt_len_median : 0
# [INFO]: strt_len_q3 : 0
# [INFO]: strt_len_max : 0
# [INFO]: strt_len_min : 0
# [INFO]: str_len_std : 0
# [INFO]: avg_track_spd : 0
# [INFO]: max_track_spd : 0
# [INFO]: min_track_spd : 0
# [INFO]: std_track_spd : 0
# ...

# %%
x.keys()
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'positionOrder', 'ClassifiedPosition',
#        'grid', 'q1', 'q2', 'q3', 'Time', 'Status', 'points', 'alt', 'raceId',
#        'round', 'ref_name', 'event_name', 'circuitId', 'ref_year', 'ref_name',
#        'strt_len_mean', 'strt_len_q1', 'strt_len_median', 'strt_len_q3',
#        'strt_len_max', 'strt_len_min', 'str_len_std', 'avg_track_spd',
#        'max_track_spd', 'min_track_spd', 'std_track_spd', 'corner_spd_mean',
#        'corner_spd_q1', 'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
#        'circuit_len', 'driverId', 'resultId', 'constructorId', 'date',
#        'tempmax', 'tempmin', 'temp', 'dew', 'humidity', 'precip',
#        'precipcover', 'preciptype', 'windspeed', 'winddir', 'prev_round',
# ...

# %%
x['circuitId']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 414   NaN
# 415   NaN
# 416   NaN
# 417   NaN
# 418   NaN
# Name: circuitId, Length: 419, dtype: float64

# %%
s1 = fastf1.get_session(2024, 1, 'R')
s1.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.4.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']

# %%
s1.results.keys()
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points'],
#       dtype='object')

# %%
x = get_standings_data(21, 2024, debug=True)

# %%
x.keys()
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'round',
#        'cum_points', 'driver_standing', 'cum_driver_wins', 'construct_points',
#        'cum_constructor_wins', 'construct_rank', 'year', 'driverId'],
#       dtype='object')

# %%
drivers = pd.read_csv("../../data/drivers.csv")

# %%
for driver in x['DriverId'].unique():
    driver_x = drivers.loc[drivers['driverRef']==driver]
    if len(driver_x['driverRef']) > 0:
        # print(x.loc[x['DriverId']==driver])
        print(driver_x['driverId'])
        x.loc[x['DriverId']==driver, 'driverId']=driver_x['driverId'].item()
    else: 
        print(driver)
        print(driver_x)
# Out:
# 829    830
# Name: driverId, dtype: int64
# 814    815
# Name: driverId, dtype: int64
# 3    4
# Name: driverId, dtype: int64
# 831    832
# Name: driverId, dtype: int64
# 0    1
# Name: driverId, dtype: int64
# 839    840
# Name: driverId, dtype: int64
# 845    847
# Name: driverId, dtype: int64
# 821    822
# Name: driverId, dtype: int64
# 452    842
# Name: driverId, dtype: int64
# 846    848
# Name: driverId, dtype: int64
# 850    852
# Name: driverId, dtype: int64
# 856    858
# Name: driverId, dtype: int64
# 824    825
# Name: driverId, dtype: int64
# 854    856
# Name: driverId, dtype: int64
# 807    807
# Name: driverId, dtype: int64
# 853    855
# Name: driverId, dtype: int64
# 844    846
# Name: driverId, dtype: int64
# 838    839
# Name: driverId, dtype: int64
# 842    844
# Name: driverId, dtype: int64
# 855    857
# Name: driverId, dtype: int64
# 816    817
# Name: driverId, dtype: int64
# 857    859
# Name: driverId, dtype: int64

# %%
x['driverId']
# Out:
# 1     830.0
# 11    815.0
# 14      4.0
# 55    832.0
# 44      1.0
#       ...
# 2     858.0
# 18    840.0
# 14      4.0
# 20    825.0
# 11    815.0
# Name: driverId, Length: 380, dtype: float64

# %%
driver = drivers.loc[drivers['driverRef']=='max_verstappen']

# %%
driver
# Out:
#      driverId       driverRef number code forename     surname         dob  \
# 829       830  max_verstappen     33  VER      Max  Verstappen  1997-09-30
#
#     nationality                                          url
# 829       Dutch  http://en.wikipedia.org/wiki/Max_Verstappen

# %%
x['DriverId']
# Out:
# 1      max_verstappen
# 11              perez
# 14             alonso
# 55              sainz
# 44           hamilton
#            ...
# 2            sargeant
# 18             stroll
# 14             alonso
# 20    kevin_magnussen
# 11              perez
# Name: DriverId, Length: 380, dtype: object

# %%
x.keys()
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'round',
#        'cum_points', 'driver_standing', 'cum_driver_wins', 'construct_points',
#        'cum_constructor_wins', 'construct_rank', 'year', 'driverId'],
#       dtype='object')

# %%
all_cols = ['driverId',
        'round',
        'prev_round', 
        'prev_driver_points', 
        'prev_driver_position',
        'prev_driver_wins', 
        'prev_construct_points', 
        'prev_construct_wins', 
        'prev_construct_position']
drop_cols = ['prev_round', 
        'prev_driver_points', 
        'prev_driver_position',
        'prev_driver_wins', 
        'prev_construct_points', 
        'prev_construct_wins', 
        'prev_construct_position']
rename_cols = {'cum_points':'prev_driver_points', 
               'driver_standing':'prev_driver_position', 
               'cum_driver_wins':'prev_driver_wins', 
               'construct_points':'prev_construct_points',
               'cum_constructor_wins':'prev_construct_wins',
               'construct_rank':'prev_construct_position'}
x1 = x.rename(columns={'round':'prev_round'})
x1['round'] = x1['prev_round'] + 1
x1 = x1.rename(columns=rename_cols)
x1 = x1[all_cols]

# %%
x1.keys()
# Out:
# Index(['driverId', 'round', 'prev_round', 'prev_driver_points',
#        'prev_driver_position', 'prev_driver_wins', 'prev_construct_points',
#        'prev_construct_wins', 'prev_construct_position'],
#       dtype='object')

# %%
x1.keys()
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'round',
#        'cum_points', 'driver_standing', 'cum_driver_wins', 'construct_points',
#        'cum_constructor_wins', 'construct_rank', 'year'],
#       dtype='object')

# %%
x['round'].max()
# Out:
# 19

# %%
s1 = fastf1.get_session(2024, 1, 'R')
s1.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.4.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']

# %%
s1.laps.keys()
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
x2 = pd.read_feather("../../data/clean_model_data.feather")

# %%
x2.keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'round', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'driverId',
#        'constructorId', 'grid', 'positionOrder', 'points', 'laps',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'prev_round', 'prev_driver_points', 'prev_driver_position',
#        'prev_driver_wins', 'prev_construct_points', 'prev_construct_position',
#        'prev_construct_wins', 'ref_year', 'ref_name', 'strt_len_mean',
#        'strt_len_q1', 'strt_len_median', 'strt_len_q3', 'strt_len_max',
#        'strt_len_min', 'str_len_std', 'avg_track_spd', 'max_track_spd',
#        'min_track_spd', 'std_track_spd', 'corner_spd_mean', 'corner_spd_q1',
#        'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
# ...

# %%
x2.loc[x2['year'] == 2023,'round'].unique()
# Out:
# array([ 3,  1,  7,  6,  8, 10, 11, 12,  9,  4,  2,  5])

# %%
x2.keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'round', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'driverId',
#        'constructorId', 'grid', 'positionOrder', 'points', 'laps',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'prev_round', 'prev_driver_points', 'prev_driver_position',
#        'prev_driver_wins', 'prev_construct_points', 'prev_construct_position',
#        'prev_construct_wins', 'ref_year', 'ref_name', 'strt_len_mean',
#        'strt_len_q1', 'strt_len_median', 'strt_len_q3', 'strt_len_max',
#        'strt_len_min', 'str_len_std', 'avg_track_spd', 'max_track_spd',
#        'min_track_spd', 'std_track_spd', 'corner_spd_mean', 'corner_spd_q1',
#        'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
# ...

# %%
x3 = x2.loc[x2['year'] == 2023]
x3 = x3.drop(columns=drop_cols)

# %%
x3.keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'round', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'driverId',
#        'constructorId', 'grid', 'positionOrder', 'points', 'laps',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'ref_year', 'ref_name', 'strt_len_mean', 'strt_len_q1',
#        'strt_len_median', 'strt_len_q3', 'strt_len_max', 'strt_len_min',
#        'str_len_std', 'avg_track_spd', 'max_track_spd', 'min_track_spd',
#        'std_track_spd', 'corner_spd_mean', 'corner_spd_q1',
#        'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
#        'circuit_len', 'regulation_id', 'engine_reg', 'tire_reg', 'aero_reg',
#        'chastech_reg', 'sporting_reg', 'pitstop_reg',
# ...

# %%
x1.keys()
# Out:
# Index(['driverId', 'round', 'prev_round', 'prev_driver_points',
#        'prev_driver_position', 'prev_driver_wins', 'prev_construct_points',
#        'prev_construct_wins', 'prev_construct_position'],
#       dtype='object')

# %%
x3.keys()
# Out:
# Index(['circuitId', 'alt', 'raceId', 'year', 'event_name', 'tempmax',
#        'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipcover',
#        'preciptype', 'windspeed', 'winddir', 'resultId', 'constructorId',
#        'grid', 'positionOrder', 'points', 'laps', 'fastestLap', 'rank',
#        'fastestLapTime', 'fastestLapSpeed', 'statusId', 'ref_year', 'ref_name',
#        'strt_len_mean', 'strt_len_q1', 'strt_len_median', 'strt_len_q3',
#        'strt_len_max', 'strt_len_min', 'str_len_std', 'avg_track_spd',
#        'max_track_spd', 'min_track_spd', 'std_track_spd', 'corner_spd_mean',
#        'corner_spd_q1', 'corner_spd_median', 'corner_spd_q3', 'corner_spd_max',
#        'corner_spd_min', 'num_slow_corners', 'num_fast_corners', 'num_corners',
#        'circuit_len', 'regulation_id', 'engine_reg', 'tire_reg', 'aero_reg',
#        'chastech_reg', 'sporting_reg', 'pitstop_reg',
#        'years_since_major_cycle', 'is_major_reg', 'cycle', 'quali_position',
# ...

# %%
x1
# Out:
#     driverId  round  prev_round  prev_driver_points  prev_driver_position  \
# 1      830.0      2           1                25.0                   1.0
# 11     815.0      2           1                18.0                   2.0
# 14       4.0      2           1                15.0                   3.0
# 55     832.0      2           1                12.0                   4.0
# 44       1.0      2           1                10.0                   5.0
# ..       ...    ...         ...                 ...                   ...
# 2      858.0     20          19                 1.0                  19.0
# 18     840.0     20          19                47.0                  11.0
# 14       4.0     20          19               175.0                   4.0
# 20     825.0     20          19                 3.0                  18.0
# 11     815.0     20          19               221.0                   2.0
#
#     prev_driver_wins  prev_construct_points  prev_construct_wins  \
# ...

# %%
print(x3.loc[(x3['driverId']==815) & (x3['round']==1)])
print(x1.loc[(x1['driverId']==815) & (x1['round']==1)])
# Out:
#      circuitId  alt  raceId  year  round          event_name  tempmax  \
# 709          3  7.0    1098  2023      1  Bahrain Grand Prix     29.6
#
#      tempmin  temp  dew  ...  chastech_reg  sporting_reg  pitstop_reg  \
# 709     20.1  24.9  8.9  ...           0.0             2            0
#
#     years_since_major_cycle  is_major_reg  cycle  quali_position        q1  \
# 709                       1             0      4             2.0  1:31.479
#
#            q2        q3
# 709  1:30.746  1:29.846
#
# [1 rows x 65 columns]
# Empty DataFrame
# Columns: [driverId, round, prev_round, prev_driver_points, prev_driver_position, prev_driver_wins, prev_construct_points, prev_construct_wins, prev_construct_position]
# Index: []

# %%
x4 = pd.merge(left=x3, right=x1, on=['round', 'driverId'], how='left')

# %%
zero_cols = ['prev_driver_points', 'prev_construct_points']
nan_cols = ['prev_driver_position', 'prev_driver_wins', 
            'prev_construct_position', 'prev_construct_wins']
x4.loc[x4['round']==1, zero_cols]=0
x4.loc[x4['round']==1, nan_cols]=np.nan
x4.loc[x4['round']==1, 'prev_round']=0

# %%
x4.loc[x4['round']==3]['driverId']
# Out:
# 0     830
# 1       1
# 2       4
# 3     840
# 4     815
# 5     846
# 6     807
# 7     857
# 8     855
# 9     852
# 10    822
# 11    832
# 12    842
# 13    839
# 14    856
# 15    858
# 16    825
# 17    847
# 18    848
# 19    844
# Name: driverId, dtype: int64
